# %% [markdown]
# # Analyse results from Pypsa-Earth

# %% [markdown]
# Sources:
# - Plot capacity - map view: https://github.com/pypsa-meets-earth/documentation/blob/main/notebooks/viz/regional_transm_system_viz.ipynb
# - Analyse energy potential: https://github.com/pypsa-meets-earth/documentation/blob/main/notebooks/build_renewable_profiles.ipynb
# - Analyse energy generation: https://pypsa.readthedocs.io/en/latest/examples/statistics.html

# %% [markdown]
# Some files are needed:
# * PyPSA network file (e.g. "elec.nc" contains a lot of details and looks perfect)
# * a country shape file (may be found in "resources/shapes/country_shapes.geojson")
# * a renewable profile file (may be found in "resources/renewable_profiles/....nc)

# %% [markdown]
# ## Import packages

# %%
import yaml
import pypsa
import warnings
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
from datetime import datetime
from cartopy import crs as ccrs
from pypsa.plot import add_legend_circles, add_legend_lines, add_legend_patches
import os
import xarray as xr
import cartopy
import sys

PATH = "../../../pypsa-eur/"
sys.path.append(os.path.join(PATH, "scripts/"))
from _helpers import rename_techs

plt.style.use(["bmh", "matplotlibrc"])
xr.set_options(display_style="html")

# %%
n = pypsa.Network("/mnt/e/H2GMA/Github/Germany/pypsa-eur/resources/H2DE/base/profile_hydro.nc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 n = pypsa.Network("/mnt/e/H2GMA/Github/Germany/pypsa-eur/resources/H2DE/base/profile_hydro.nc")
#
# File ~/anaconda3/envs/pypsa-eur-20250202/lib/python3.12/site-packages/pypsa/components.py:382, in Network.__init__(self, import_name, name, ignore_standard_types, override_components, override_component_attrs, **kwargs)
#     380     self.import_from_hdf5(import_name)
#     381 elif str(import_name).endswith(".nc"):
# --> 382     self.import_from_netcdf(import_name)
#     383 elif isinstance(import_name, Path) and import_name.is_dir():
#     384     self.import_from_csv_folder(import_name)
#
# File ~/anaconda3/envs/pypsa-eur-20250202/lib/python3.12/site-packages/pypsa/utils.py:85, in deprecated_kwargs.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      82 @functools.wraps(f)
#      83 def wrapper(*args: Any, **kwargs: Any) -> Any:
#      84     rename_kwargs(f.__name__, kwargs, aliases)
# ---> 85     return f(*args, **kwargs)
#
# File ~/anaconda3/envs/pypsa-eur-20250202/lib/python3.12/site-packages/pypsa/io.py:781, in import_from_netcdf(n, path, skip_time)
#     779 basename = "" if isinstance(path, xr.Dataset) else Path(path).name
#     780 with ImporterNetCDF(path=path) as importer:
# --> 781     _import_from_importer(n, importer, basename=basename, skip_time=skip_time)
#
# File ~/anaconda3/envs/pypsa-eur-20250202/lib/python3.12/site-packages/pypsa/utils.py:85, in deprecated_kwargs.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      82 @functools.wraps(f)
#      83 def wrapper(*args: Any, **kwargs: Any) -> Any:
#      84     rename_kwargs(f.__name__, kwargs, aliases)
# ---> 85     return f(*args, **kwargs)
#
# File ~/anaconda3/envs/pypsa-eur-20250202/lib/python3.12/site-packages/pypsa/io.py:866, in _import_from_importer(n, importer, basename, skip_time)
#     863 pypsa_version = None
#     865 if attrs is not None:
# --> 866     n.name = attrs.pop("name")
#     868     try:
#     869         pypsa_version = [int(s) for s in attrs.pop("pypsa_version").split(".")]
#
# KeyError: 'name'

# %% [markdown]
# ## Path settings

# %%
cluster = 256
planning_year = 2050

with open("/mnt/e/H2GMA/Github/Europe/pypsa-eur/results/myopic/config.main") as file:
    config = yaml.safe_load(file)

# Network file
run_name = config["run"]["name"]
sector_opts = config["scenario"]["sector_opts"][0]
#"mnt/e/H2GMA/Github/Europe/pypsa-eur/results/myopic-martavp-2025-2050-5-steps-all-sectors"

results_path = f"{PATH}results/myopic/{run_name}/networks/base_s_{cluster}__{sector_opts}_{planning_year}.nc"
network_path = f"{PATH}resources/myopic/{run_name}/networks/base.nc"
# Country shape file
regions_onshore_path = f"{PATH}resources/myopic/{run_name}/country_shapes.geojson"
# Renewable profile file
solar_path = f"{PATH}resources/myopic/{run_name}/profile_{cluster}_solar.nc"
onwind_path = f"{PATH}resources/myopic/{run_name}/profile_{cluster}_onwind.nc" 
#ToDo: Add more REE

# %% [markdown]
# ## Energy system analysis setup - power and energy generation

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
n = pypsa.Network(results_path)
regions_onshore = gpd.read_file(regions_onshore_path)
country_coordinates = regions_onshore.total_bounds[[0, 2, 1, 3]]
warnings.simplefilter(action='default', category=FutureWarning)
# Out:
# INFO:pypsa.io:Imported network base_s_256__144H-T-H-B-I-A_2050.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.loads
# Out:
#                                                    bus               carrier  \
# Load
# AL0 0                                AL0 0 low voltage           electricity
# AT0 0                                AT0 0 low voltage           electricity
# AT0 1                                AT0 1 low voltage           electricity
# AT0 2                                AT0 2 low voltage           electricity
# AT0 3                                AT0 3 low voltage           electricity
# ...                                                ...                   ...
# SK0 0 urban decentral heat  SK0 0 urban decentral heat  urban decentral heat
# SK0 1 rural heat                      SK0 1 rural heat            rural heat
# SK0 1 urban decentral heat  SK0 1 urban decentral heat  urban decentral heat
# XK0 0 rural heat                      XK0 0 rural heat            rural heat
# XK0 0 urban decentral heat  XK0 0 urban decentral heat  urban decentral heat
#
#                            type  p_set  q_set  sign  active
# Load
# AL0 0                              0.0    0.0  -1.0    True
# AT0 0                              0.0    0.0  -1.0    True
# AT0 1                              0.0    0.0  -1.0    True
# AT0 2                              0.0    0.0  -1.0    True
# AT0 3                              0.0    0.0  -1.0    True
# ...                         ...    ...    ...   ...     ...
# SK0 0 urban decentral heat         0.0    0.0  -1.0    True
# SK0 1 rural heat                   0.0    0.0  -1.0    True
# SK0 1 urban decentral heat         0.0    0.0  -1.0    True
# XK0 0 rural heat                   0.0    0.0  -1.0    True
# XK0 0 urban decentral heat         0.0    0.0  -1.0    True
#
# [2555 rows x 7 columns]

# %%
n.generators_t
# Out:
#                     bus control type        p_nom  p_nom_mod  \
# Generator
# BE0 2 nuclear     BE0 2   Slack       3008.000000        0.0
# BE0 3 nuclear     BE0 3      PQ       2911.000000        0.0
# BG0 1 nuclear     BG0 1      PQ       2080.000000        0.0
# CH0 1 nuclear     CH0 1      PQ       2970.000000        0.0
# CZ0 1 nuclear     CZ0 1      PQ       2164.000000        0.0
# ...                 ...     ...  ...          ...        ...
# SE1 8 solar-2025  SE1 8      PQ        207.098327        0.0
# SE1 9 solar-2025  SE1 9      PQ        203.233937        0.0
# SI0 0 solar-2025  SI0 0      PQ        664.384000        0.0
# SK0 0 solar-2025  SK0 0      PQ         47.977511        0.0
# SK0 1 solar-2025  SK0 1      PQ         48.102489        0.0
#
#                   p_nom_extendable  p_nom_min  p_nom_max  p_min_pu  p_max_pu  \
# Generator
# BE0 2 nuclear                False     3008.0        inf       0.0     0.883
# BE0 3 nuclear                False     2911.0        inf       0.0     0.883
# BG0 1 nuclear                False     2080.0        inf       0.0     0.876
# CH0 1 nuclear                False     2970.0        inf       0.0     0.834
# CZ0 1 nuclear                False     2164.0        inf       0.0     0.839
# ...                            ...        ...        ...       ...       ...
# SE1 8 solar-2025             False        0.0        inf       0.0     1.000
# SE1 9 solar-2025             False        0.0        inf       0.0     1.000
# SI0 0 solar-2025             False        0.0        inf       0.0     1.000
# SK0 0 solar-2025             False        0.0        inf       0.0     1.000
# SK0 1 solar-2025             False        0.0        inf       0.0     1.000
#
#                   ...  min_up_time  min_down_time  up_time_before  \
# Generator         ...
# BE0 2 nuclear     ...            0              0               1
# BE0 3 nuclear     ...            0              0               1
# BG0 1 nuclear     ...            0              0               1
# CH0 1 nuclear     ...            0              0               1
# CZ0 1 nuclear     ...            0              0               1
# ...               ...          ...            ...             ...
# SE1 8 solar-2025  ...            0              0               1
# SE1 9 solar-2025  ...            0              0               1
# SI0 0 solar-2025  ...            0              0               1
# SK0 0 solar-2025  ...            0              0               1
# SK0 1 solar-2025  ...            0              0               1
#
#                   down_time_before  ramp_limit_up ramp_limit_down  \
# Generator
# BE0 2 nuclear                    0            NaN             NaN
# BE0 3 nuclear                    0            NaN             NaN
# BG0 1 nuclear                    0            NaN             NaN
# CH0 1 nuclear                    0            NaN             NaN
# CZ0 1 nuclear                    0            NaN             NaN
# ...                            ...            ...             ...
# SE1 8 solar-2025                 0            NaN             NaN
# SE1 9 solar-2025                 0            NaN             NaN
# SI0 0 solar-2025                 0            NaN             NaN
# SK0 0 solar-2025                 0            NaN             NaN
# SK0 1 solar-2025                 0            NaN             NaN
#
#                   ramp_limit_start_up  ramp_limit_shut_down  weight  \
# Generator
# BE0 2 nuclear                     1.0                   1.0     1.0
# BE0 3 nuclear                     1.0                   1.0     1.0
# BG0 1 nuclear                     1.0                   1.0     1.0
# CH0 1 nuclear                     1.0                   1.0     1.0
# CZ0 1 nuclear                     1.0                   1.0     1.0
# ...                               ...                   ...     ...
# SE1 8 solar-2025                  1.0                   1.0     1.0
# SE1 9 solar-2025                  1.0                   1.0     1.0
# SI0 0 solar-2025                  1.0                   1.0     1.0
# SK0 0 solar-2025                  1.0                   1.0     1.0
# SK0 1 solar-2025                  1.0                   1.0     1.0
#
#                     p_nom_opt
# Generator
# BE0 2 nuclear     3008.000000
# BE0 3 nuclear     2911.000000
# BG0 1 nuclear     2080.000000
# CH0 1 nuclear     2970.000000
# CZ0 1 nuclear     2164.000000
# ...                       ...
# SE1 8 solar-2025   207.098327
# SE1 9 solar-2025   203.233937
# SI0 0 solar-2025   664.384000
# SK0 0 solar-2025    47.977511
# SK0 1 solar-2025    48.102489
#
# [3679 rows x 37 columns]

# %%
n.loads_t

# %%
n.links_t
# Out:
#                              bus0    bus1 type carrier  efficiency  active  \
# Link
# relation/10377412-320-DC   FR0 32  GB2 14           DC    0.974452    True
# relation/13295785-515-DC    NO1 9  GB2 18           DC    0.964429    True
# relation/14126301-450-DC   GB2 17   NL0 5           DC    0.974161    True
# relation/15772117-320-DC   GB2 17  FR0 11           DC    0.976688    True
# relation/15775538-600-DC   GB2 23  GB2 24           DC    0.973961    True
# ...                           ...     ...  ...     ...         ...     ...
# RO0 3 CCGT-2025            EU gas   RO0 3         CCGT    0.580000    True
# RS0 0 CCGT-2025            EU gas   RS0 0         CCGT    0.580000    True
# SI0 0 CCGT-2025            EU gas   SI0 0         CCGT    0.580000    True
# PL0 0 coal-2025           EU coal   PL0 0         coal    0.330000    True
# DE0 6 oil-2025             EU oil   DE0 6          oil    0.350000    True
#
#                           build_year  lifetime        p_nom  p_nom_mod  ...  \
# Link                                                                    ...
# relation/10377412-320-DC           0       inf  1000.000000        0.0  ...
# relation/13295785-515-DC           0       inf  1400.000000        0.0  ...
# relation/14126301-450-DC           0       inf  1000.000000        0.0  ...
# relation/15772117-320-DC           0       inf  1000.000000        0.0  ...
# relation/15775538-600-DC           0       inf  2250.000000        0.0  ...
# ...                              ...       ...          ...        ...  ...
# RO0 3 CCGT-2025                 2025      39.0   137.931034        0.0  ...
# RS0 0 CCGT-2025                 2025      38.0   325.862069        0.0  ...
# SI0 0 CCGT-2025                 2025      39.0   189.655172        0.0  ...
# PL0 0 coal-2025                 2025      43.0   363.636364        0.0  ...
# DE0 6 oil-2025                  2025      38.5    91.628571        0.0  ...
#
#                                        tags  reversed  under_construction  \
# Link
# relation/10377412-320-DC  relation/10377412     False                 0.0
# relation/13295785-515-DC  relation/13295785     False                 0.0
# relation/14126301-450-DC  relation/14126301     False                 0.0
# relation/15772117-320-DC  relation/15772117     False                 0.0
# relation/15775538-600-DC  relation/15775538     False                 0.0
# ...                                     ...       ...                 ...
# RO0 3 CCGT-2025                                 False                 NaN
# RS0 0 CCGT-2025                                 False                 NaN
# SI0 0 CCGT-2025                                 False                 NaN
# PL0 0 coal-2025                                 False                 NaN
# DE0 6 oil-2025                                  False                 NaN
#
#                           length_original  \
# Link
# relation/10377412-320-DC       243.975197
# relation/13295785-515-DC       688.316647
# relation/14126301-450-DC       256.842206
# relation/15772117-320-DC       145.509177
# relation/15775538-600-DC       265.630337
# ...                                   ...
# RO0 3 CCGT-2025                       NaN
# RS0 0 CCGT-2025                       NaN
# SI0 0 CCGT-2025                       NaN
# PL0 0 coal-2025                       NaN
# DE0 6 oil-2025                        NaN
#
#                                                                    geometry  \
# Link
# relation/10377412-320-DC  LINESTRING (-1.194439480272105 50.818035638860...
# relation/13295785-515-DC  LINESTRING (-1.5404269162550226 55.14647596191...
# relation/14126301-450-DC  LINESTRING (0.7161575436002887 51.440498299145...
# relation/15772117-320-DC  LINESTRING (1.1448358124246543 51.098446880403...
# relation/15775538-600-DC  LINESTRING (-4.894821189854914 55.718036768358...
# ...                                                                     ...
# RO0 3 CCGT-2025
# RS0 0 CCGT-2025
# SI0 0 CCGT-2025
# PL0 0 coal-2025
# DE0 6 oil-2025
#
#                           project_status  voltage   dc  underwater_fraction  \
# Link
# relation/10377412-320-DC                    320.0  1.0             0.888446
# relation/13295785-515-DC                    515.0  1.0             0.983350
# relation/14126301-450-DC                    450.0  1.0             0.977109
# relation/15772117-320-DC                    320.0  1.0             0.714775
# relation/15775538-600-DC                    600.0  1.0             0.892448
# ...                                  ...      ...  ...                  ...
# RO0 3 CCGT-2025                               NaN  NaN                  NaN
# RS0 0 CCGT-2025                               NaN  NaN                  NaN
# SI0 0 CCGT-2025                               NaN  NaN                  NaN
# PL0 0 coal-2025                               NaN  NaN                  NaN
# DE0 6 oil-2025                                NaN  NaN                  NaN
#
#                           underground
# Link
# relation/10377412-320-DC          1.0
# relation/13295785-515-DC          1.0
# relation/14126301-450-DC          1.0
# relation/15772117-320-DC          1.0
# relation/15775538-600-DC          1.0
# ...                               ...
# RO0 3 CCGT-2025                   NaN
# RS0 0 CCGT-2025                   NaN
# SI0 0 CCGT-2025                   NaN
# PL0 0 coal-2025                   NaN
# DE0 6 oil-2025                    NaN
#
# [15689 rows x 51 columns]

# %%
n.lines_t
# Out:
# {'s_max_pu': Empty DataFrame
#  Columns: []
#  Index: [2013-01-01 00:00:00, 2013-01-07 00:00:00, 2013-01-13 00:00:00, 2013-01-19 00:00:00, 2013-01-25 00:00:00, 2013-01-31 00:00:00, 2013-02-06 00:00:00, 2013-02-12 00:00:00, 2013-02-18 00:00:00, 2013-02-24 00:00:00, 2013-03-02 00:00:00, 2013-03-08 00:00:00, 2013-03-14 00:00:00, 2013-03-20 00:00:00, 2013-03-26 00:00:00, 2013-04-01 00:00:00, 2013-04-07 00:00:00, 2013-04-13 00:00:00, 2013-04-19 00:00:00, 2013-04-25 00:00:00, 2013-05-01 00:00:00, 2013-05-07 00:00:00, 2013-05-13 00:00:00, 2013-05-19 00:00:00, 2013-05-25 00:00:00, 2013-05-31 00:00:00, 2013-06-06 00:00:00, 2013-06-12 00:00:00, 2013-06-18 00:00:00, 2013-06-24 00:00:00, 2013-06-30 00:00:00, 2013-07-06 00:00:00, 2013-07-12 00:00:00, 2013-07-18 00:00:00, 2013-07-24 00:00:00, 2013-07-30 00:00:00, 2013-08-05 00:00:00, 2013-08-11 00:00:00, 2013-08-17 00:00:00, 2013-08-23 00:00:00, 2013-08-29 00:00:00, 2013-09-04 00:00:00, 2013-09-10 00:00:00, 2013-09-16 00:00:00, 2013-09-22 00:00:00, 2013-09-28 00:00:00, 2013-10-04 00:00:00, 2013-10-10 00:00:00, 2013-10-16 00:00:00, 2013-10-22 00:00:00, 2013-10-28 00:00:00, 2013-11-03 00:00:00, 2013-11-09 00:00:00, 2013-11-15 00:00:00, 2013-11-21 00:00:00, 2013-11-27 00:00:00, 2013-12-03 00:00:00, 2013-12-09 00:00:00, 2013-12-15 00:00:00, 2013-12-21 00:00:00, 2013-12-27 00:00:00]
#
#  [61 rows x 0 columns],
# ...                      ...            ...           ...               ...
# 2013-12-03         -0.000012      -0.008099  19982.302234      6.580456e-08
# 2013-12-09         -0.000011      -0.008427  11326.215313      6.568379e-08
# 2013-12-15         -0.000013      -0.008849  12703.671929      6.565059e-08
# 2013-12-21         -0.000015      -0.009415  15281.105948      6.565339e-08
# 2013-12-27         -0.000017      -0.012401   2934.922821      7.893752e-08
#
# Store       co2 atmosphere    co2 stored  co2 sequestered-2050  EU gas Store  \
# snapshot
# 2013-01-01     3745.562088 -1.474913e-05             -0.001566 -11699.190679
# 2013-01-07   -34571.990900 -1.590350e-06              0.000030  16344.278949
# 2013-01-13   -83117.376286 -4.330607e-06             -0.000023  51421.320448
# 2013-01-19   -60327.804856 -5.617692e-06             -0.000007  28647.652471
# 2013-01-25   -10193.829901 -1.107935e-06             -0.000017  -8161.394028
# ...                    ...           ...                   ...           ...
# 2013-12-03      571.209426  9.275911e-07             -0.000005   9452.364857
# 2013-12-09     -292.962819  2.534305e-06             -0.000005  16012.434059
# 2013-12-15     1306.657516  9.715856e-06             -0.000008   5731.852085
# 2013-12-21     5382.302666 -1.976432e-05             -0.000007 -17421.340598
# 2013-12-27     5371.403204  3.385191e-05             -0.000680 -36581.979385
#
# Store       DE0 10 H2 Store-2050  DE0 14 H2 Store-2050  ...  \
# snapshot                                                ...
# 2013-01-01             -0.000049             -0.000257  ...
# 2013-01-07             26.581058              0.000331  ...
# 2013-01-13             21.217418             89.378388  ...
# 2013-01-19              0.000778              0.000198  ...
# 2013-01-25            -16.521524            -79.361548  ...
# ...                          ...                   ...  ...
# 2013-12-03            -12.799192            -10.341828  ...
# 2013-12-09             22.246089              5.903908  ...
# 2013-12-15            -19.478484            -21.382696  ...
# 2013-12-21             -8.769906            -13.483527  ...
# 2013-12-27            -23.460525            -10.001485  ...
#
# Store       NL0 8 urban central water tanks-2040  \
# snapshot
# 2013-01-01                             -0.972875
# 2013-01-07                             -0.972856
# 2013-01-13                             28.702185
# 2013-01-19                             -0.000002
# 2013-01-25                             -0.000017
# ...                                          ...
# 2013-12-03                             -0.466554
# 2013-12-09                             28.212466
# 2013-12-15                             -0.000024
# 2013-12-21                             -0.000042
# 2013-12-27                            -35.609980
#
# Store       NO1 3 urban central water tanks-2040  \
# snapshot
# 2013-01-01                             -0.156627
# 2013-01-07                             -0.156636
# 2013-01-13                              4.621135
# 2013-01-19                             -0.000032
# 2013-01-25                             -0.000017
# ...                                          ...
# 2013-12-03                              4.621126
# 2013-12-09                              0.000006
# 2013-12-15                             -0.000045
# 2013-12-21                             -1.233953
# 2013-12-27                             -4.293110
#
# Store       NO1 7 urban central water tanks-2040  \
# snapshot
# 2013-01-01                             -0.287085
# 2013-01-07                             -0.287064
# 2013-01-13                              8.469925
# 2013-01-19                              0.000013
# 2013-01-25                             -0.000032
# ...                                          ...
# 2013-12-03                              8.469897
# 2013-12-09                              0.000089
# 2013-12-15                             -0.000017
# 2013-12-21                             -8.756958
# 2013-12-27                             -0.288010
#
# Store       PL0 10 urban central water tanks-2040  \
# snapshot
# 2013-01-01                              -0.550470
# 2013-01-07                              -0.000306
# 2013-01-13                              -1.082563
# 2013-01-19                              16.239966
# 2013-01-25                              -0.000048
# ...                                           ...
# 2013-12-03                              16.239710
# 2013-12-09                               0.000190
# 2013-12-15                               0.000064
# 2013-12-21                             -16.790416
# 2013-12-27                              -0.551981
#
# Store       PL0 8 urban central water tanks-2040  \
# snapshot
# 2013-01-01                             -0.057346
# 2013-01-07                              0.096779
# 2013-01-13                             -0.206341
# 2013-01-19                              1.690786
# 2013-01-25                              0.000002
# ...                                          ...
# 2013-12-03                              1.690769
# 2013-12-09                             -0.000015
# 2013-12-15                              0.000019
# 2013-12-21                             -1.748087
# 2013-12-27                             -0.057436
#
# Store       PT0 3 urban central water tanks-2040  \
# snapshot
# 2013-01-01                             16.891006
# 2013-01-07                              0.000040
# 2013-01-13                              0.000043
# 2013-01-19                              0.000111
# 2013-01-25                             -0.000915
# ...                                          ...
# 2013-12-03                              0.000049
# 2013-12-09                             -0.000004
# 2013-12-15                              0.000030
# 2013-12-21                             -0.000021
# 2013-12-27                            -20.956455
#
# Store       SE1 4 urban central water tanks-2040  \
# snapshot
# 2013-01-01                             -0.051684
# 2013-01-07                              1.524247
# 2013-01-13                              0.000168
# 2013-01-19                              0.000081
# 2013-01-25                              0.000028
# ...                                          ...
# 2013-12-03                              1.524207
# 2013-12-09                              0.000353
# 2013-12-15                              0.000005
# 2013-12-21                             -1.576244
# 2013-12-27                             -0.051872
#
# Store       SE1 7 urban central water tanks-2040  \
# snapshot
# 2013-01-01                             -0.835320
# 2013-01-07                             -0.835296
# 2013-01-13                             24.643910
# 2013-01-19                             -0.000016
# 2013-01-25                             -0.000030
# ...                                          ...
# 2013-12-03                             24.643518
# 2013-12-09                              0.000318
# 2013-12-15                              0.000009
# 2013-12-21                            -25.479154
# 2013-12-27                             -0.837681
#
# Store       SE1 9 urban central water tanks-2040  co2 sequestered-2030
# snapshot
# 2013-01-01                             -0.582516         -39130.118751
# 2013-01-07                              2.403428         -43128.760929
# 2013-01-13                             14.297040          82258.879680
# 2013-01-19                              0.000209              0.000000
# 2013-01-25                             -4.213475        -201581.347427
# ...                                          ...                   ...
# 2013-12-03                             17.185313         -38036.279471
# 2013-12-09                             -0.000087         -37644.740379
# 2013-12-15                              0.000070         -38399.518733
# 2013-12-21                            -17.767752         -69701.950479
# 2013-12-27                             -0.584150              0.001551
#
# [61 rows x 1960 columns]

# %%
n.storage_units_t.p
# Out:
# StorageUnit    AT0 1 PHS    AT0 3 PHS  AT0 4 PHS  BA0 0 PHS  BE0 1 PHS  \
# snapshot
# 2013-01-01     -0.000173 -1864.398425  -0.000444  -0.000606  -0.000017
# 2013-01-07     -0.000004  1009.997970  -0.000003  -0.000003  -0.000003
# 2013-01-13    890.140680  3733.299995   1.804214   0.020917   4.269980
# 2013-01-19     -0.000004  3733.295754  -0.000003  -0.000005  -0.000004
# 2013-01-25   -787.708806 -2782.106505  -0.000028  -0.000030  -0.000083
# ...                  ...          ...        ...        ...        ...
# 2013-12-03     -0.000224 -3733.299613  -2.401331  -0.025900  -0.000054
# 2013-01-13     71.999998     7.143135
# 2013-01-19     71.999997    10.439105
# 2013-01-25     71.999983     6.874280
# ...                  ...          ...
# 2013-12-03      0.000168     1.018128
# 2013-12-09     71.999964     2.318664
# 2013-12-15     71.999852     0.000089
# 2013-12-21     71.997009     1.030440
# 2013-12-27      3.624268     6.411051
#
# [61 rows x 208 columns]

# %%
n.statistics()
# Out:
#                                        Optimal Capacity  Installed Capacity  \
# Generator Offshore Wind (AC)               5.600760e+04        4.010193e+04
#           Offshore Wind (DC)               1.169989e+05        9.893397e+04
#           Offshore Wind (Floating)         1.070000e-02        0.000000e+00
#           Onshore Wind                     7.772736e+05        7.338658e+05
#           Run of River                     4.780433e+04        4.780433e+04
# ...                                                 ...                 ...
# Store     oil                              8.211161e+07        0.000000e+00
#           rural water tanks                2.767000e-02        0.000000e+00
#           uranium                          4.392400e-01        0.000000e+00
#           urban central water tanks        2.623027e+06        2.602519e+06
#           urban decentral water tanks      2.796000e-02        0.000000e+00
#
#                                              Supply    Withdrawal  \
# Generator Offshore Wind (AC)           2.446281e+08  0.000000e+00
#           Offshore Wind (DC)           5.914443e+08  0.000000e+00
#           Offshore Wind (Floating)     2.877624e+01  0.000000e+00
#           Onshore Wind                 2.275061e+09  0.000000e+00
#           Run of River                 1.704778e+08  0.000000e+00
# ...                                             ...           ...
# Store     oil                          8.248259e+07  8.248259e+07
#           rural water tanks            0.000000e+00  7.114600e-01
#           uranium                      5.600000e-04  5.600000e-04
#           urban central water tanks    2.614995e+07  2.844756e+07
#           urban decentral water tanks  0.000000e+00  7.234100e-01
#
#                                        Energy Balance  Transmission  \
# Generator Offshore Wind (AC)             2.446281e+08           0.0
#           Offshore Wind (DC)             5.914443e+08           0.0
#           Offshore Wind (Floating)       2.877624e+01           0.0
#           Onshore Wind                   2.275061e+09           0.0
#           Run of River                   1.704778e+08           0.0
# ...                                               ...           ...
# Store     oil                            0.000000e+00           0.0
#           rural water tanks             -7.114600e-01           0.0
#           uranium                        0.000000e+00           0.0
#           urban central water tanks     -2.297601e+06           0.0
#           urban decentral water tanks   -7.234100e-01           0.0
#
#                                        Capacity Factor   Curtailment  \
# Generator Offshore Wind (AC)                  0.498603  2.232159e+06
#           Offshore Wind (DC)                  0.577069  1.723676e+05
#           Offshore Wind (Floating)            0.306542  8.277240e+00
#           Onshore Wind                        0.334130  5.284112e+07
#           Run of River                        0.407096  5.708614e+04
# ...                                                ...           ...
# Store     oil                                 0.563715  0.000000e+00
#           rural water tanks                   0.490423  0.000000e+00
#           uranium                             0.000637  0.000000e+00
#           urban central water tanks           0.438659  0.000000e+00
#           urban decentral water tanks         0.493562  0.000000e+00
#
#                                        Capital Expenditure  \
# Generator Offshore Wind (AC)                  1.060535e+10
#           Offshore Wind (DC)                  2.565079e+10
#           Offshore Wind (Floating)            2.199024e+03
#           Onshore Wind                        8.665437e+10
#           Run of River                        1.473188e+10
# ...                                                    ...
# Store     oil                                 2.241027e+08
#           rural water tanks                   8.142443e+02
#           uranium                             4.392000e-02
#           urban central water tanks           6.411604e+08
#           urban decentral water tanks         8.228272e+02
#
#                                        Operational Expenditure       Revenue  \
# Generator Offshore Wind (AC)                      8.227433e+06  1.072271e+10
#           Offshore Wind (DC)                      1.997409e+07  2.608682e+10
#           Offshore Wind (Floating)                7.150000e-01  1.399175e+03
#           Onshore Wind                            8.559994e+07  9.172501e+10
#           Run of River                            1.708465e+06  7.360875e+09
# ...                                                        ...           ...
# Store     oil                                     0.000000e+00  2.241027e+08
#           rural water tanks                      -7.150000e-03 -2.260131e+01
#           uranium                                 0.000000e+00  0.000000e+00
#           urban central water tanks              -4.591511e+04  5.333672e+08
#           urban decentral water tanks            -7.250000e-03 -2.291079e+01
#
#                                        Market Value
# Generator Offshore Wind (AC)              43.832715
#           Offshore Wind (DC)              44.106971
#           Offshore Wind (Floating)        48.695122
#           Onshore Wind                    40.317613
#           Run of River                    43.177910
# ...                                             ...
# Store     oil                              2.716969
#           rural water tanks                     NaN
#           uranium                          0.000000
#           urban central water tanks       20.396486
#           urban decentral water tanks           NaN
#
# [114 rows x 12 columns]

# %% [markdown]
# FENES color setting

# %%
def rgb_to_hex(r, g, b):
    return '#{:02x}{:02x}{:02x}'.format(r, g, b)

FENES_color = n.carriers.color
FENES_color["nuclear"] = rgb_to_hex(206,55,62) #adapted
FENES_color["OCGT"] = rgb_to_hex(228,147,44)
FENES_color["coal"] = rgb_to_hex(80,80,80)
FENES_color["CCGT"] = rgb_to_hex(218,137,34) #adapted
FENES_color["biomass"] = rgb_to_hex(29,152,56)
FENES_color["lignite"] = rgb_to_hex(185,100,40)
FENES_color["oil"] = rgb_to_hex(0,0,0)
FENES_color["geothermal"] = rgb_to_hex(176,25,32)
FENES_color["hydro"] = rgb_to_hex(27,90,166)
FENES_color["offwind-ac"] = rgb_to_hex(18,143,207)
FENES_color["offwind-dc"] = rgb_to_hex(8,133,197) #adapted
FENES_color["onwind"] = rgb_to_hex(28,153,218) #adapted
FENES_color["solar"] = rgb_to_hex(228,203,58)
FENES_color["PHS"] = "#08ad97"
FENES_color["ror"] = "#4adbc8"
FENES_color["H2"] = "#ea048a"
FENES_color["battery"] = rgb_to_hex(140,191,62)

n.carriers.color = FENES_color

# Set export
n.carriers.loc["export", "nice_name"] = "Export"
n.carriers.loc["export", "color"] = "#800080"
# Out:
# /tmp/ipykernel_60521/2081982108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FENES_color["nuclear"] = rgb_to_hex(206,55,62) #adapted
# /tmp/ipykernel_60521/2081982108.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FENES_color["OCGT"] = rgb_to_hex(228,147,44)
# /tmp/ipykernel_60521/2081982108.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FENES_color["coal"] = rgb_to_hex(80,80,80)
# /tmp/ipykernel_60521/2081982108.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FENES_color["CCGT"] = rgb_to_hex(218,137,34) #adapted

# %% [markdown]
# ## Data import check

# %% [markdown]
# Country check

# %%
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={"projection": ccrs.EqualEarth(n.buses.x.mean())})
with plt.rc_context({"patch.linewidth": 0.}):
    regions_onshore.plot(
    ax=ax,
    facecolor="green",
    edgecolor="white",
    aspect="equal",
    transform=ccrs.PlateCarree(),
    linewidth=0,
    )
ax.set_title(", ".join(regions_onshore.name.values))
# Out:
# Text(0.5, 1.0, 'AL, AT, BA, BE, BG, CH, CZ, DE, DK, EE, ES, FI, FR, GB, GR, HR, HU, IE, IT, LT, LU, LV, ME, MK, NL, NO, PL, PT, RO, RS, SE, SI, SK, XK')

# %% [markdown]
# Component check

# %%
for c in n.iterate_components(list(n.components.keys())[2:]):
    print("Component '{}' has {} entries".format(c.name,len(c.df)))
# Out:
# Component 'Bus' has 1547 entries
# Component 'Carrier' has 102 entries
# Component 'GlobalConstraint' has 2 entries
# Component 'Line' has 257 entries
# Component 'LineType' has 36 entries
# Component 'TransformerType' has 14 entries
# Component 'Link' has 8198 entries
# Component 'Load' has 1283 entries
# Component 'Generator' has 1978 entries
# Component 'StorageUnit' has 137 entries
# Component 'Store' has 997 entries

# %% [markdown]
# Snapshot check

# %%
print(n.snapshots)
print(f"Time steps: " + str(len(n.snapshots)))
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-07', '2013-01-13', '2013-01-19',
#                '2013-01-25', '2013-01-31', '2013-02-06', '2013-02-12',
#                '2013-02-18', '2013-02-24', '2013-03-02', '2013-03-08',
#                '2013-03-14', '2013-03-20', '2013-03-26', '2013-04-01',
#                '2013-04-07', '2013-04-13', '2013-04-19', '2013-04-25',
#                '2013-05-01', '2013-05-07', '2013-05-13', '2013-05-19',
#                '2013-05-25', '2013-05-31', '2013-06-06', '2013-06-12',
#                '2013-06-18', '2013-06-24', '2013-06-30', '2013-07-06',
#                '2013-07-12', '2013-07-18', '2013-07-24', '2013-07-30',
#                '2013-08-05', '2013-08-11', '2013-08-17', '2013-08-23',
#                '2013-08-29', '2013-09-04', '2013-09-10', '2013-09-16',
#                '2013-09-22', '2013-09-28', '2013-10-04', '2013-10-10',
#                '2013-10-16', '2013-10-22', '2013-10-28', '2013-11-03',
#                '2013-11-09', '2013-11-15', '2013-11-21', '2013-11-27',
#                '2013-12-03', '2013-12-09', '2013-12-15', '2013-12-21',
#                '2013-12-27'],
#               dtype='datetime64[ns]', name='snapshot', freq=None)
# Time steps: 61

# %% [markdown]
# ## Analyse energy system

# %% [markdown]
# Analyse the current capacity of the energy system - map view

# %%
default_color = '#000000'
# Set a default color for empty entries
n.carriers.color = n.carriers.color.replace('', default_color)

# %%
# Scale settings
bus_scale = 2e8
line_scale = 1e4

# Legend settings
bus_sizes = [100, 1000]  # in MW
line_sizes = [100, 1000]  # in MW

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={"projection": ccrs.EqualEarth(n.buses.x.mean())})
gen = n.generators[(n.generators.carrier != "load") & (n.generators.carrier != "export")].groupby(["bus", "carrier"]).p_nom.sum()
sto = n.storage_units.groupby(["bus", "carrier"]).p_nom.sum()
buses = pd.concat([gen, sto])

with plt.rc_context({"patch.linewidth": 0.}):
    n.plot(
        bus_sizes=buses / bus_scale,
        bus_alpha=0.7,
        line_widths=n.lines.s_nom_opt / line_scale,
        link_widths=n.links[n.links.carrier != "export"].p_nom_opt / line_scale,
        line_colors="teal",
        ax=ax,
        margin=0.2,
        color_geomap=None,
    )
regions_onshore.plot(
    ax=ax,
    facecolor="whitesmoke",
    edgecolor="white",
    aspect="equal",
    transform=ccrs.PlateCarree(),
    linewidth=0,
)
ax.set_extent(regions_onshore.total_bounds[[0, 2, 1, 3]])
legend_kwargs = {"loc": "upper left", "frameon": False}
legend_circles_dict = {"bbox_to_anchor": (1, 0.67), "labelspacing": 2.5, **legend_kwargs}

add_legend_circles(
    ax,
    [s / bus_scale for s in bus_sizes],
    [f"{s / 1000} GW" for s in bus_sizes],
    legend_kw=legend_circles_dict,    
)
add_legend_lines(
    ax,
    [s / line_scale for s in line_sizes],
    [f"{s / 1000} GW" for s in line_sizes],
    legend_kw={"bbox_to_anchor": (1, 0.8), **legend_kwargs},
)
add_legend_patches(
    ax,
    n.carriers.color,
    n.carriers.nice_name,
    legend_kw={"bbox_to_anchor": (1, 0), **legend_kwargs, "loc":"lower left"},
)
fig.tight_layout()
# Out:
# /home/alex-charly/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /tmp/ipykernel_60521/3677568634.py:55: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout()

# %% [markdown]
# Analyse the current generation capacity of the energy system - pie chart view

# %%
generator_capacity_by_carrier = n.generators[(n.generators.carrier != "load") & (n.generators.carrier != "export")].groupby(["carrier"]).p_nom.sum()
plt.figure(figsize=(8, 8))
# Filter out carriers with zero capacity
filtered_capacity = generator_capacity_by_carrier[generator_capacity_by_carrier > 0]
# Get the corresponding colors
filtered_colors = n.carriers[n.carriers.index.isin(filtered_capacity.index)].color.reindex(filtered_capacity.index)
# Plot the pie chart
plt.pie(filtered_capacity, labels=filtered_capacity.index, autopct='%1.1f%%', colors=filtered_colors)
plt.title("Generator Capacity by Carrier")
# Out:
# Text(0.5, 1.0, 'Generator Capacity by Carrier')

# %% [markdown]
# Analyse the current gernation capacity of the energy system - tabular view

# %%
generator_capacity_by_carrier/1e3 # in GW
# Out:
# carrier
# biogas                           3.593675e+05
# coal                             0.000000e+00
# gas                              0.000000e+00
# lignite                          0.000000e+00
# nuclear                          1.052861e+02
# offwind-ac                       3.164423e+01
# offwind-dc                       1.146364e+02
# offwind-float                    1.464032e+00
# oil primary                      0.000000e+00
# onwind                           6.732595e+02
# ror                              4.780433e+01
# rural solar thermal              0.000000e+00
# solar                            2.017186e+03
# solar rooftop                    8.359368e+02
# solar-hsat                       2.404825e+02
# solid biomass                    1.025547e+06
# urban central solar thermal      0.000000e+00
# urban decentral solar thermal    0.000000e+00
# Name: p_nom, dtype: float64

# %% [markdown]
# Analyse the future capacity of the energy system - map view

# %%
bus_scale = 5e3 
line_scale = 1e3

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={"projection": ccrs.EqualEarth(n.buses.x.mean())})
gen = n.generators[(n.generators.carrier != "load") & (n.generators.carrier != "export")].groupby(["bus", "carrier"]).p_nom_opt.sum()
sto = n.storage_units.groupby(["bus", "carrier"]).p_nom_opt.sum()
buses = pd.concat([gen, sto])

with plt.rc_context({"patch.linewidth": 0.}):
    n.plot(
        bus_sizes=buses / bus_scale,
        bus_alpha=0.7,
        line_widths=n.lines.s_nom_opt / line_scale,
        link_widths=n.links[n.links.carrier != "export"].p_nom_opt / line_scale,
        line_colors="teal",
        ax=ax,
        margin=0.2,
        color_geomap=None,
    )
regions_onshore.plot(
    ax=ax,
    facecolor="whitesmoke",
    edgecolor="white",
    aspect="equal",
    transform=ccrs.PlateCarree(),
    linewidth=0,
)
ax.set_extent(regions_onshore.total_bounds[[0, 2, 1, 3]])
legend_kwargs = {"loc": "upper left", "frameon": False}
legend_circles_dict = {"bbox_to_anchor": (1, 0.67), "labelspacing": 2.5, **legend_kwargs}

add_legend_circles(
    ax,
    [s / bus_scale for s in bus_sizes],
    [f"{s / 1000} GW" for s in bus_sizes],
    legend_kw=legend_circles_dict,    
)
add_legend_lines(
    ax,
    [s / line_scale for s in line_sizes],
    [f"{s / 1000} GW" for s in line_sizes],
    legend_kw={"bbox_to_anchor": (1, 0.8), **legend_kwargs},
)
add_legend_patches(
    ax,
    n.carriers.color,
    n.carriers.nice_name,
    legend_kw={"bbox_to_anchor": (1, 0), **legend_kwargs, "loc":"lower left"},
)
fig.tight_layout()
# Out:
# /home/alex-charly/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /tmp/ipykernel_60521/958174134.py:50: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout()

# %% [markdown]
# Calculate emissions of future energy system

# %%
co2_emissions = pd.DataFrame(data=n.carriers[["co2_emissions", "nice_name"]]).set_index("nice_name").squeeze().rename_axis("carrier")

energy_production = n.statistics.energy_balance().Generator.droplevel(1).drop(["load", "export"], errors="ignore")

co2_emissions_technology = energy_production * co2_emissions.loc[energy_production.index]
co2_emissions_technology
# Out:
# carrier
# Offshore Wind (AC)               0.0
# Offshore Wind (DC)               0.0
# Offshore Wind (Floating)         0.0
# Onshore Wind                     0.0
# Run of River                     0.0
# Solar                            0.0
# biogas                           0.0
# coal                             0.0
# gas                              0.0
# lignite                          0.0
# nuclear                          0.0
# oil primary                      0.0
# rural solar thermal              0.0
# solar rooftop                    0.0
# solar-hsat                       0.0
# solid biomass                    0.0
# urban central solar thermal      0.0
# urban decentral solar thermal    0.0
# dtype: float64

# %%
co2_emissions_sum = co2_emissions_technology.sum()
co2_emissions_sum
# Out:
# 0.0

# %%
n.global_constraints
# Out:
#                                       type  investment_period  \
# GlobalConstraint
# CO2Limit                    co2_atmosphere                NaN
# co2_sequestration_limit  operational_limit                NaN
#
#                         carrier_attribute sense     constant          mu
# GlobalConstraint
# CO2Limit                    co2_emissions    <=          0.0 -260.883972
# co2_sequestration_limit   co2 sequestered    >= -200000000.0  149.018656

# %% [markdown]
# Analys the future generation capacity expansion of the energy system - bar chart

# %%
generation_capacity_expansion = n.statistics.optimal_capacity(comps=["Generator"]).droplevel(0).div(1e3)-n.statistics.installed_capacity(comps=["Generator"]).droplevel(0).div(1e3)
generation_capacity_expansion.plot.bar(title="Generator capacity expansion in GW")
# Out:
# <Axes: title={'center': 'Generator capacity expansion in GW'}, xlabel='carrier'>

# %% [markdown]
# Plot the future generation capacity expansion of the energy system - tabular chart

# %%
generation_capacity_expansion # In GW
# Out:
# carrier
# Offshore Wind (AC)                21.621167
# Offshore Wind (DC)                20.138685
# Offshore Wind (Floating)           0.608395
# Onshore Wind                      44.297880
# Run of River                       0.000000
# Solar                            317.110221
# biogas                             0.000000
# coal                                    NaN
# gas                                     NaN
# lignite                                 NaN
# nuclear                            0.000000
# oil primary                             NaN
# rural solar thermal                     NaN
# solar rooftop                    151.864629
# solar-hsat                         0.000037
# solid biomass                      0.000000
# urban central solar thermal             NaN
# urban decentral solar thermal           NaN
# dtype: float64

# %% [markdown]
# Analyse the future energy generation of the energy system - bar chart view

# %%
# Color for figure
n.carriers.loc["H2 electrolysis", "nice_name"] = "H2 Electrolysis"
n.carriers.loc["H2 electrolysis", "color"] = "#ea048a"
n.carriers.loc["H2 fuel cell", "nice_name"] = "H2 Fuel Cell"
n.carriers.loc["H2 fuel cell", "color"] = "#ea048a"
n.carriers.loc["battery charger", "nice_name"] = "Battery Charger"
n.carriers.loc["battery charger", "color"] = rgb_to_hex(140,191,62)
n.carriers.loc["battery discharger", "nice_name"] = "Battery Discharger"
n.carriers.loc["battery discharger", "color"] = rgb_to_hex(140,191,62)
n.carriers.loc["load", "nice_name"] = "Load"
n.carriers.loc["load", "color"] = "#8b0000"

# %%
# Set the index of n.carriers to nice_name
color_setting = n.carriers.set_index('nice_name')

# Calculate energy balance
energy_balance = n.statistics.energy_balance().loc[:, :, "AC"].groupby("carrier").sum().sort_values(ascending=False).div(1e6).to_frame().T
#energy_balance.drop(columns=["Load"], inplace=True)
energy_balance.rename(columns={'-': 'Load'}, inplace=True)

# Get the colors for the carriers
colors = color_setting.loc[energy_balance.columns, 'color']

# Plot the bar chart with colors
fig, ax = plt.subplots()
energy_balance.plot.bar(stacked=True, ax=ax, title="Energy Balance in TWh", color=colors)

# Adjust legend
ax.legend(bbox_to_anchor=(1, 0), loc="lower left", title=None, ncol=1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 10
#       7 energy_balance.rename(columns={'-': 'Load'}, inplace=True)
#       9 # Get the colors for the carriers
# ---> 10 colors = color_setting.loc[energy_balance.columns, 'color']
#      12 # Plot the bar chart with colors
#      13 fig, ax = plt.subplots()
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexing.py:1089, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1087             return section
#    1088         # This is an elided recursive call to iloc/loc
# -> 1089         return getattr(section, self.name)[new_key]
#    1091 raise IndexingError("not applicable")
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['CCGT'] not in index"

# %% [markdown]
# Analyse the future energy generation of the energy system - tabular view

# %%
n.statistics.energy_balance()/1e6 # In TWh
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 n.statistics.energy_balance()/1e6 # In TWh
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pypsa/statistics/expressions.py:819, in StatisticsAccessor.energy_balance(self, comps, aggregate_time, aggregate_groups, aggregate_across_components, groupby, at_port, bus_carrier, nice_names, kind)
#     814         logger.warning(
#     815             "Argument 'kind' is not recognized. Falling back to energy balance."
#     816         )
#     817     return self._aggregate_timeseries(p, weights, agg=aggregate_time)
# --> 819 df = self._aggregate_components(
#     820     func,
#     821     comps=comps,
#     822     agg=aggregate_groups,
#     823     aggregate_across_components=aggregate_across_components,
#     824     groupby=groupby,
#     825     at_port=at_port,
#     826     bus_carrier=bus_carrier,
#     827     nice_names=nice_names,
#     828 )
#     830 df.attrs["name"] = "Energy Balance"
#     831 df.attrs["unit"] = "carrier dependent"
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pypsa/statistics/abstract.py:216, in AbstractStatisticsAccessor._aggregate_components(self, func, agg, comps, groupby, aggregate_across_components, at_port, bus_carrier, nice_names)
#     208         warnings.warn(
#     209             "Passing `groupby=None` is deprecated. Drop the "
#     210             "argument to get the default grouping (by carrier), which "
#    (...)
#     213             stacklevel=2,
#     214         )
#     215         groupby = "carrier"
# --> 216     grouping = self._get_grouping(
#     217         n, c, groupby, port=port, nice_names=nice_names
#     218     )
#     219     vals = self._aggregate_components_groupby(vals, grouping, agg)
#     220 values.append(vals)
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pypsa/statistics/abstract.py:105, in AbstractStatisticsAccessor._get_grouping(self, n, c, groupby, port, nice_names)
#     103         by = groupby(n, c, nice_names=nice_names)
#     104 elif isinstance(groupby, (str, list)):
# --> 105     by = groupers[groupby](n, c, port=port, nice_names=nice_names)
#     106 elif groupby is not False:
#     107     msg = f"Argument `groupby` must be a function, list, string, False or dict, got {repr(groupby)}."
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pypsa/statistics/grouping.py:159, in Groupers._multi_grouper.<locals>.multi_grouper(n, c, port, nice_names)
#     157     if "nice_names" in signature(method).parameters:
#     158         kwargs["nice_names"] = nice_names
# --> 159     grouped_data.append(method(n, c, **kwargs))
#     161 return grouped_data[0] if scalar_passed else grouped_data
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pypsa/statistics/grouping.py:252, in Groupers.bus_carrier(self, n, c, port, nice_names)
#     231 """
#     232 Grouper method to group by the carrier of the attached bus of a component.
#     233
#    (...)
#     249
#     250 """
#     251 bus = f"bus{port}"
# --> 252 buses_carrier = self.carrier(n, "Bus", nice_names=nice_names)
#     253 return n.static(c)[bus].map(buses_carrier).rename("bus_carrier")
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pypsa/statistics/grouping.py:223, in Groupers.carrier(self, n, c, nice_names)
#     221 carrier_series = static.get("carrier", fall_back).rename("carrier")
#     222 if nice_names:
# --> 223     carrier_series = carrier_series.replace(
#     224         n.carriers.nice_name[lambda ds: ds != ""]
#     225     ).replace("", "-")
#     226 return carrier_series
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/generic.py:8051, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    8048     else:
#    8049         to_replace, value = keys, values
# -> 8051     return self.replace(
#    8052         to_replace, value, inplace=inplace, limit=limit, regex=regex
#    8053     )
#    8054 else:
#    8055     # need a non-zero len on all axes
#    8056     if not self.size:
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/generic.py:8099, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    8094     if len(to_replace) != len(value):
#    8095         raise ValueError(
#    8096             f"Replacement lists must match in length. "
#    8097             f"Expecting {len(to_replace)} got {len(value)} "
#    8098         )
# -> 8099     new_data = self._mgr.replace_list(
#    8100         src_list=to_replace,
#    8101         dest_list=value,
#    8102         inplace=inplace,
#    8103         regex=regex,
#    8104     )
#    8106 elif to_replace is None:
#    8107     if not (
#    8108         is_re_compilable(regex)
#    8109         or is_list_like(regex)
#    8110         or is_dict_like(regex)
#    8111     ):
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/internals/base.py:278, in DataManager.replace_list(self, src_list, dest_list, inplace, regex)
#     275 """do a list replace"""
#     276 inplace = validate_bool_kwarg(inplace, "inplace")
# --> 278 bm = self.apply_with_block(
#     279     "replace_list",
#     280     src_list=src_list,
#     281     dest_list=dest_list,
#     282     inplace=inplace,
#     283     regex=regex,
#     284     using_cow=using_copy_on_write(),
#     285     already_warned=_AlreadyWarned(),
#     286 )
#     287 bm._consolidate_inplace()
#     288 return bm
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1119, in Block.replace_list(self, src_list, dest_list, inplace, regex, using_cow, already_warned)
#    1114     m = mib[blk_num : blk_num + 1]
#    1116 # error: Argument "mask" to "_replace_coerce" of "Block" has
#    1117 # incompatible type "Union[ExtensionArray, ndarray[Any, Any], bool]";
#    1118 # expected "ndarray[Any, dtype[bool_]]"
# -> 1119 result = blk._replace_coerce(
#    1120     to_replace=src,
#    1121     value=dest,
#    1122     mask=m,
#    1123     inplace=inplace,
#    1124     regex=regex,
#    1125     using_cow=using_cow,
#    1126 )
#    1128 if using_cow and i != src_len:
#    1129     # This is ugly, but we have to get rid of intermediate refs
#    1130     # that did not go out of scope yet, otherwise we will trigger
#    1131     # many unnecessary copies
#    1132     for b in result:
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1223, in Block._replace_coerce(self, to_replace, value, mask, inplace, regex, using_cow)
#    1221         return [self]
#    1222     return [self] if inplace else [self.copy()]
# -> 1223 return self.replace(
#    1224     to_replace=to_replace,
#    1225     value=value,
#    1226     inplace=inplace,
#    1227     mask=mask,
#    1228     using_cow=using_cow,
#    1229 )
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/internals/blocks.py:875, in Block.replace(self, to_replace, value, inplace, mask, using_cow, already_warned)
#     873         return [self.copy(deep=False)]
#     874     else:
# --> 875         return [self] if inplace else [self.copy()]
#     877 elif self._can_hold_element(value):
#     878     # TODO(CoW): Maybe split here as well into columns where mask has True
#     879     # and rest?
#     880     blk = self._maybe_copy(using_cow, inplace)
#
# File ~/anaconda3/envs/pypsa-eur/lib/python3.12/site-packages/pandas/core/internals/blocks.py:796, in Block.copy(self, deep)
#     794 refs: BlockValuesRefs | None
#     795 if deep:
# --> 796     values = values.copy()
#     797     refs = None
#     798 else:
#
# KeyboardInterrupt:

# %%
n.statistics.energy_balance().Load
# Out:
# carrier                            bus_carrier
# H2 for industry                    Hydrogen Storage             -1.796700e+08
# agriculture electricity            low voltage                  -3.752588e+07
# agriculture heat                   rural heat                   -2.148117e+08
# agriculture machinery oil          agriculture machinery oil    -1.028476e+08
# electricity                        low voltage                  -1.574888e+09
# gas for industry                   gas for industry             -2.313800e+08
# industry electricity               low voltage                  -1.769360e+09
# industry methanol                  industry methanol            -8.730000e+06
# kerosene for aviation              kerosene for aviation        -7.439070e+08
# land transport EV                  EV battery                   -9.796810e+08
# low-temperature heat for industry  urban central heat           -5.917000e+07
#                                    urban decentral heat         -2.200000e+05
# naphtha for industry               naphtha for industry         -2.768600e+08
# process emissions                  process emissions             1.231300e+08
# rural heat                         rural heat                   -5.719304e+08
# shipping methanol                  shipping methanol            -5.029697e+08
# solid biomass for industry         solid biomass for industry   -7.481700e+08
# urban central heat                 urban central heat           -1.356496e+09
# urban decentral heat               urban decentral heat         -7.863747e+08
# dtype: float64

# %% [markdown]
# ## Analyse pv and wind potential - map view

# %%
solar = xr.open_dataset(solar_path)
wind = xr.open_dataset(onwind_path)

def plot_voronoi(n, carrier, voronoi, cmap, projection, title=None, filename=None):
    g = n.generators.loc[n.generators.carrier == carrier]
    br = gpd.read_file(f"/mnt/e/H2GMA/Github/Europe/pypsa-eur/resources/myopic/{run_name}/regions_{voronoi}_base_s_{cluster}.geojson").set_index("name")
    br_area = br.to_crs("ESRI:54009")
    br_area = br_area.geometry.area * 1e-6
    br["p_nom_max"] = g.groupby("bus").sum().p_nom_max / br_area

    fig, ax = plt.subplots(figsize=(8, 4), subplot_kw={"projection": projection})
    plt.rcParams.update({"font.size": 10})
    br.plot(
        ax=ax,
        column="p_nom_max",
        transform=ccrs.PlateCarree(),
        linewidth=0.25,
        edgecolor="k",
        cmap=cmap,
        vmin=0,
        vmax=br["p_nom_max"].max(),
        legend=True,
        legend_kwds={"label": r"potential density"},
    )
    ax.coastlines()
    ax.add_feature(cartopy.feature.BORDERS.with_scale("110m"))
    ax.set_extent(country_coordinates, crs=ccrs.PlateCarree()) 
    
    if title is not None:
        plt.title(title)

# %% [markdown]
# Plot pv energy potential

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plot_voronoi(
    pypsa.Network(network_path),
    "solar",
    "onshore",
    "OrRd",
    ccrs.PlateCarree(),
    title="Solar Photovoltaic Potential Density [MW/km2]",
)
warnings.simplefilter(action='default', category=FutureWarning)
# Out:
# INFO:pypsa.io:Imported network base.nc has buses, carriers, lines, links, shapes, transformers

# %% [markdown]
# Plot wind energy potential

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plot_voronoi(
    pypsa.Network(network_path),
    "onwind",
    "onshore",
    "Blues",
    ccrs.PlateCarree(),
    title="Onshore Wind Potential Density [MW/km2]",
)
warnings.simplefilter(action='default', category=FutureWarning)
# Out:
# INFO:pypsa.io:Imported network base.nc has buses, carriers, lines, links, shapes, transformers

# %% [markdown]
# Levelized cost of electricity

# %%
# Calculation levelzied cost of electricity in €/MWh based on overall costs and electricity generation
# n.statistics.market_value() ?
lcoe = n.objective/n.statistics.energy_balance().Generator.sum()
lcoe

# %%
# Calculation levelzied cost of electricity in €/MWh based on overall costs and electricity demand
lcoe = n.objective/n.statistics.energy_balance().Load.sum()*(-1)
lcoe

# %% [markdown]
# Average THG value

# %%
THG_Strom = co2_emissions_technology.sum()/n.statistics.energy_balance().Generator.sum()
THG_Strom #t CO2/MWh Strom bzw. kg CO2/kWh Strom
THG_H2 = THG_Strom/0.65 #Wirkungsgrad Elektrolyseur
THG_H2 #kg CO2/kWh H2
THG_H2 = THG_H2*33.33 #kWh/kg
THG_H2 # kg CO2/kg H2

# %% [markdown]
# ### H2-Demand-Europe

# %%
df_h2_eu = n.statistics.energy_balance().loc[:, :, "Hydrogen Storage"].div(1e6)
df_h2_eu
# Out:
# component  carrier
# Link       Fischer-Tropsch   -1305.444699
#            H2 Electrolysis    2028.399641
#            H2 Fuel Cell         -0.000016
#            SMR                   0.000024
#            SMR CC               39.045396
#            Sabatier             -0.000041
#            methanolisation    -582.280306
# Load       H2 for industry    -179.720000
# dtype: float64

# %%
df_h2_eu[df_h2_eu < 0].sum()
# Out:
# -2067.4450607372396

# %% [markdown]
# ### H2-Demand-Germany

# %%
df_h2_de = n.statistics.energy_balance(groupby=["carrier", "bus_carrier", "country"])
df_h2_de
# Out:
# component  carrier               bus_carrier           country
# Generator  Offshore Wind (AC)    AC                    AL         6.816000e-02
#                                                        BA         2.313000e-02
#                                                        BE         3.749759e+06
#                                                        BG         2.368000e-01
#                                                        DE         1.824150e+07
#                                                                       ...
# Load       urban decentral heat  urban decentral heat  RS        -4.042778e+06
#                                                        SE        -2.753379e+07
#                                                        SI        -2.077078e+06
#                                                        SK        -5.571043e+06
#                                                        XK        -6.369583e+05
# Length: 3570, dtype: float64

# %%
df_h2_de = n.statistics.energy_balance(groupby=["carrier", "bus_carrier", "country"])
idx = pd.IndexSlice
df_h2_de = df_h2_de.loc[idx[:,:,"Hydrogen Storage",:]].div(1e6)

# %%
df_h2_de[df_h2_de < 0].sum()
# Out:
# -2159.59992536154

# %%
n.loads.to_csv("load.csv")

# %%
# Filter loads that are connected to buses containing "DE"
de_loads = n.loads[n.loads.bus.str.contains("DE")]

# %%
de_loads_t = n.loads_t.p.loc[:, n.loads_t.p.columns.str.contains("DE")]
de_loads_t
# Out:
# Load             DE0 0  DE0 0 H2 for industry  DE0 0 agriculture electricity  \
# snapshot
# 2013-01-01  467.164382                    0.0                       3.714516
# 2013-01-07  576.692299                    0.0                       3.714516
# 2013-01-13  591.314743                    0.0                       3.714516
# 2013-01-19  583.553277                    0.0                       3.714516
# 2013-01-25  570.261624                    0.0                       3.714516
# ...                ...                    ...                            ...
# 2013-12-03  606.893718                    0.0                       3.714516
# 2013-12-09  615.304167                    0.0                       3.714516
# 2013-12-15  592.685428                    0.0                       3.714516
# 2013-12-21  474.491132                    0.0                       3.714516
# 2013-12-27  464.529586                    0.0                       3.714516
#
# Load        DE0 0 agriculture heat  DE0 0 industry electricity  \
# snapshot
# 2013-01-01                25.78528                  512.557078
# 2013-01-07                25.78528                  512.557078
# 2013-01-13                25.78528                  512.557078
# 2013-01-19                25.78528                  512.557078
# 2013-01-25                25.78528                  512.557078
# ...                            ...                         ...
# 2013-12-03                25.78528                  512.557078
# 2013-12-09                25.78528                  512.557078
# 2013-12-15                25.78528                  512.557078
# 2013-12-21                25.78528                  512.557078
# 2013-12-27                25.78528                  512.557078
#
# Load        DE0 0 land transport EV  DE0 0 low-temperature heat for industry  \
# snapshot
# 2013-01-01               171.515813                                10.273973
# 2013-01-07               183.883177                                10.273973
# 2013-01-13               190.523962                                10.273973
# 2013-01-19               183.201371                                10.273973
# 2013-01-25               177.401180                                10.273973
# ...                             ...                                      ...
# 2013-12-03               177.731283                                10.273973
# 2013-12-09               181.296452                                10.273973
# 2013-12-15               179.621945                                10.273973
# 2013-12-21               167.709016                                10.273973
# 2013-12-27               170.932232                                10.273973
#
# Load        DE0 0 rural heat  DE0 0 urban central heat  \
# snapshot
# 2013-01-01        574.336371                 62.542144
# 2013-01-07        729.625472                 79.452293
# 2013-01-13        990.146773                107.821663
# 2013-01-19       1015.472659                110.579515
# 2013-01-25        794.959597                 86.566828
# ...                      ...                       ...
# 2013-12-03        751.184304                 81.799934
# 2013-12-09        654.544949                 71.276427
# 2013-12-15        688.820619                 75.008864
# 2013-12-21        562.496655                 61.252863
# 2013-12-27        654.724982                 71.296032
#
# Load        DE0 0 urban decentral heat  ...        DE0 9  \
# snapshot                                ...
# 2013-01-01                   36.256316  ...   853.707986
# 2013-01-07                   46.059300  ...  1045.962741
# 2013-01-13                   62.505312  ...  1022.765647
# 2013-01-19                   64.104067  ...  1003.272168
# 2013-01-25                   50.183668  ...  1033.893761
# ...                                ...  ...          ...
# 2013-12-03                   47.420252  ...  1105.674195
# 2013-12-09                   41.319668  ...  1121.716534
# 2013-12-15                   43.483399  ...  1105.780826
# 2013-12-21                   35.508906  ...   867.922340
# 2013-12-27                   41.331033  ...   838.230803
#
# Load        DE0 9 H2 for industry  DE0 9 agriculture electricity  \
# snapshot
# 2013-01-01            1640.410959                      22.159004
# 2013-01-07            1640.410959                      22.159004
# 2013-01-13            1640.410959                      22.159004
# 2013-01-19            1640.410959                      22.159004
# 2013-01-25            1640.410959                      22.159004
# ...                           ...                            ...
# 2013-12-03            1640.410959                      22.159004
# 2013-12-09            1640.410959                      22.159004
# 2013-12-15            1640.410959                      22.159004
# 2013-12-21            1640.410959                      22.159004
# 2013-12-27            1640.410959                      22.159004
#
# Load        DE0 9 agriculture heat  DE0 9 industry electricity  \
# snapshot
# 2013-01-01              153.822509                 3948.630137
# 2013-01-07              153.822509                 3948.630137
# 2013-01-13              153.822509                 3948.630137
# 2013-01-19              153.822509                 3948.630137
# 2013-01-25              153.822509                 3948.630137
# ...                            ...                         ...
# 2013-12-03              153.822509                 3948.630137
# 2013-12-09              153.822509                 3948.630137
# 2013-12-15              153.822509                 3948.630137
# 2013-12-21              153.822509                 3948.630137
# 2013-12-27              153.822509                 3948.630137
#
# Load        DE0 9 land transport EV  DE0 9 low-temperature heat for industry  \
# snapshot
# 2013-01-01               997.694849                                76.484018
# 2013-01-07              1072.848980                                76.484018
# 2013-01-13              1126.296515                                76.484018
# 2013-01-19              1082.007919                                76.484018
# 2013-01-25              1027.935318                                76.484018
# ...                             ...                                      ...
# 2013-12-03              1033.480305                                76.484018
# 2013-12-09              1069.469028                                76.484018
# 2013-12-15              1028.518144                                76.484018
# 2013-12-21               978.805180                                76.484018
# 2013-12-27               990.946192                                76.484018
#
# Load        DE0 9 rural heat  DE0 9 urban central heat  \
# snapshot
# 2013-01-01        197.777116               2390.002201
# 2013-01-07        281.825866               3405.674296
# 2013-01-13        437.470523               5286.534331
# 2013-01-19        449.830697               5435.898638
# 2013-01-25        288.074476               3481.184510
# ...                      ...                       ...
# 2013-12-03        286.682111               3464.358716
# 2013-12-09        276.504627               3341.370740
# 2013-12-15        211.892158               2560.572904
# 2013-12-21        197.451590               2386.068437
# 2013-12-27        231.703850               2799.983751
#
# Load        DE0 9 urban decentral heat
# snapshot
# 2013-01-01                 1385.508522
# 2013-01-07                 1974.303940
# 2013-01-13                 3064.657583
# 2013-01-19                 3151.245587
# 2013-01-25                 2018.077977
# ...                                ...
# 2013-12-03                 2008.323893
# 2013-12-09                 1937.026516
# 2013-12-15                 1484.390089
# 2013-12-21                 1383.228079
# 2013-12-27                 1623.178986
#
# [61 rows x 400 columns]
